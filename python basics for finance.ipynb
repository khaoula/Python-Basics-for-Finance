# %%
                                              Python Basics For Finance
This part has basics to get started in Python for finance

# %%
import pandas_datareader as pdr

# %%
import datetime

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
#Importing Financial Data Into Python

yahooData = pdr.get_data_yahoo('aapl', 
                          start=datetime.datetime(2010, 1, 1), 
                          end=datetime.datetime(2018, 1, 1))

# %%
#ake the peek at the first rows of the DataFrame

yahooData.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2010-01-04  30.642857  30.340000  30.490000  30.572857  123432400.0  26.681330
# 2010-01-05  30.798571  30.464285  30.657143  30.625713  150476200.0  26.727465
# 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0  26.302330
# 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0  26.253704
# 2010-01-08  30.285715  29.865715  30.042856  30.282858  111902700.0  26.428249

# %%
#ake the peek at the last rows of the DataFrame

yahooData.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-12-26  171.470001  169.679993  170.800003  170.570007  33185500.0
# 2017-12-27  170.779999  169.710007  170.100006  170.600006  21498200.0
# 2017-12-28  171.850006  170.479996  171.000000  171.080002  16480200.0
# 2017-12-29  170.589996  169.220001  170.520004  169.229996  25999900.0
# 2018-01-02  172.300003  169.259995  170.160004  172.259995  25555900.0
#
#              Adj Close
# Date
# 2017-12-26  166.056595
# 2017-12-27  166.085815
# 2017-12-28  166.553101
# 2017-12-29  164.752060
# 2018-01-02  167.701889

# %%
#Get summary statistics about the data.
yahooData.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  2014.000000  2014.000000  2014.000000  2014.000000  2.014000e+03
# mean     89.067868    87.514598    88.323493    88.315843  8.583260e+07
# std      36.036821    35.614117    35.823765    35.842635  6.066024e+07
# min      28.000000    27.178572    27.481428    27.435715  1.147590e+07
# 25%      58.464287    57.321428    57.885356    57.933928  3.919338e+07
# 50%      86.717857    85.056427    85.882858    86.202145  7.067290e+07
# 75%     114.205000   111.945002   113.057499   113.050003  1.133827e+08
# max     177.199997   174.860001   175.110001   176.419998  4.702495e+08
#
#          Adj Close
# count  2014.000000
# mean     81.365862
# std      35.776478
# min      23.943514
# 25%      50.930146
# 50%      75.801384
# 75%     106.274061
# max     171.751816

# %%
# Save data to a csv file 
yahooData.to_csv('C:/Users/khaoula ilaje/Desktop/data/aapl_ohlc.csv')

# %%
# Read Data from CSV file
df = pd.read_csv('C:/Users/khaoula ilaje/Desktop/data/aapl_ohlc.csv', header=0, index_col='Date', parse_dates=True)

# %%
# Inspect the index
yahooData.index
# Out:
# DatetimeIndex(['2010-01-04', '2010-01-05', '2010-01-06', '2010-01-07',
#                '2010-01-08', '2010-01-11', '2010-01-12', '2010-01-13',
#                '2010-01-14', '2010-01-15',
#                ...
#                '2017-12-18', '2017-12-19', '2017-12-20', '2017-12-21',
#                '2017-12-22', '2017-12-26', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2018-01-02'],
#               dtype='datetime64[ns]', name='Date', length=2014, freq=None)

# %%
# Inspect the columns
yahooData.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
# Select the last 10 rows of `Close`
lastclosed = yahooData['Close'][-10:]

# %%
type(lastclosed)
# Out:
# pandas.core.series.Series

# %%
print(lastclosed)
# Out:
# Date
# 2017-12-18    176.419998
# 2017-12-19    174.539993
# 2017-12-20    174.350006
# 2017-12-21    175.009995
# 2017-12-22    175.009995
# 2017-12-26    170.570007
# 2017-12-27    170.600006
# 2017-12-28    171.080002
# 2017-12-29    169.229996
# 2018-01-02    172.259995
# Name: Close, dtype: float64

# %%
# Inspect the first rows of 2007 

print(yahooData.loc['2010'].head())
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2010-01-04  30.642857  30.340000  30.490000  30.572857  123432400.0  26.681330
# 2010-01-05  30.798571  30.464285  30.657143  30.625713  150476200.0  26.727465
# 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0  26.302330
# 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0  26.253704
# 2010-01-08  30.285715  29.865715  30.042856  30.282858  111902700.0  26.428249

# %%
# inspect line 2 to 4
print(yahooData.iloc[2:4])
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2010-01-06  30.747143  30.107143  30.625713  30.138571  138040000.0  26.302330
# 2010-01-07  30.285715  29.864286  30.250000  30.082857  119282800.0  26.253704

# %%
#inspect lines between two dates
print(yahooData.loc['2010-10-01':'2010-10-03'])
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2010-10-01  40.939999  40.192856  40.878571  40.360001  112035700.0  35.222706

# %%
#inspect lines between two dates

print(yahooData.loc[pd.Timestamp('2010-10-01'):pd.Timestamp('2010-10-03')])
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2010-10-01  40.939999  40.192856  40.878571  40.360001  112035700.0  35.222706

# %%
#inspect data in line : 1 and 2 clomun: 0 and 3
print(yahooData.iloc[[1,2], [0, 3]])
# Out:
#                  High      Close
# Date
# 2010-01-05  30.798571  30.625713
# 2010-01-06  30.747143  30.138571

# %%
# Sample 20 rows
print(yahooData.sample(10))
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-12-01  171.669998  168.500000  169.949997  171.050003   39759300.0
# 2011-05-11   50.000000   49.320000   49.860001   49.604286   84000000.0
# 2011-03-30   50.125713   49.634285   50.091427   49.804287   82351500.0
# 2015-02-12  127.480003  125.570000  126.059998  126.459999   74474500.0
# 2016-01-11   99.059998   97.339996   98.970001   98.529999   49739400.0
# 2017-08-28  162.000000  159.929993  160.139999  161.470001   25966000.0
# 2016-12-05  110.029999  108.250000  110.000000  109.110001   34324500.0
# 2013-07-01   58.895714   57.317142   57.527142   58.459999   97763400.0
# 2011-09-22   58.545715   56.671429   57.290001   57.402859  242120200.0
# 2017-09-15  160.970001  158.000000  158.470001  159.880005   49114600.0
#
#              Adj Close
# Date
# 2017-12-01  166.523895
# 2011-05-11   43.290321
# 2011-03-30   43.464855
# 2015-02-12  117.002419
# 2016-01-11   92.350006
# ...

# %%
# Resample to monthly level based on the mean / averge
print(yahooData.resample('M').mean())
# Out:
#                   High         Low        Open       Close        Volume  \
# Date
# 2010-01-31   30.175338   29.328647   29.915639   29.673609  1.995920e+08
# 2010-02-28   28.636466   28.046090   28.298872   28.399398  1.417905e+08
# 2010-03-31   32.097205   31.612174   31.828137   31.915838  1.321106e+08
# 2010-04-30   36.162381   35.445714   35.857347   35.878368  1.472277e+08
# 2010-05-31   36.516857   34.974714   35.997071   35.923071  2.260332e+08
# 2010-06-30   37.842532   36.912467   37.483702   37.306493  1.892188e+08
# 2010-07-31   36.922721   35.869660   36.497075   36.421428  1.865441e+08
# 2010-08-31   36.249610   35.602078   35.944351   35.903312  1.089673e+08
# 2010-09-30   39.398095   38.654285   38.977279   39.121564  1.410705e+08
# 2010-10-31   43.326463   42.524149   42.918095   42.990612  1.456497e+08
# 2010-11-30   44.853130   44.114625   44.492381   44.512585  1.131915e+08
# 2010-12-31   46.151558   45.714675   45.973052   45.926559  7.924130e+07
# ...

# %%
print(yahooData.asfreq("M", method="bfill"))
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-01-31   28.000000   27.328571   27.481428   27.818571  187469100.0
# 2010-02-28   29.928572   29.350000   29.392857   29.855715  137523400.0
# 2010-03-31   33.801430   33.494286   33.641430   33.571430  107664900.0
# 2010-04-30   38.652859   37.285713   38.472858   37.298573  135615900.0
# 2010-05-31   37.991428   36.994286   37.098572   37.261429  219118200.0
# 2010-06-30   36.852856   35.715714   36.672855   35.932858  184863000.0
# 2010-07-31   37.512856   37.088570   37.205715   37.407143  107013900.0
# 2010-08-31   34.937141   34.335712   34.549999   34.728573  105196700.0
# 2010-09-30   41.428570   40.178570   41.285713   40.535713  168347900.0
# 2010-10-31   43.657143   43.171429   43.174286   43.454285  105972300.0
# 2010-11-30   44.908573   44.410000   44.791428   44.450001  125464500.0
# 2010-12-31   46.211430   45.901428   46.135715   46.080002   48377000.0
# ...

# %%
# Add a column `test column` to YahooData 
yahooData['test column'] = yahooData.Open - yahooData.Close
print(yahooData)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
# 2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
# 2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
# 2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
# 2010-01-08   30.285715   29.865715   30.042856   30.282858  111902700.0
# 2010-01-11   30.428572   29.778572   30.400000   30.015715  115557400.0
# 2010-01-12   29.967142   29.488571   29.884285   29.674286  148614900.0
# 2010-01-13   30.132856   29.157143   29.695715   30.092857  151473000.0
# 2010-01-14   30.065714   29.860001   30.015715   29.918571  108223500.0
# 2010-01-15   30.228571   29.410000   30.132856   29.418571  148516900.0
# 2010-01-19   30.741428   29.605715   29.761429   30.719999  182501900.0
# 2010-01-20   30.792856   29.928572   30.701429   30.247143  153038200.0
# ...

# %%
# Delete the new `test column` column
del yahooData['test column']

# %%
print(yahooData)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
# 2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
# 2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
# 2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
# 2010-01-08   30.285715   29.865715   30.042856   30.282858  111902700.0
# 2010-01-11   30.428572   29.778572   30.400000   30.015715  115557400.0
# 2010-01-12   29.967142   29.488571   29.884285   29.674286  148614900.0
# 2010-01-13   30.132856   29.157143   29.695715   30.092857  151473000.0
# 2010-01-14   30.065714   29.860001   30.015715   29.918571  108223500.0
# 2010-01-15   30.228571   29.410000   30.132856   29.418571  148516900.0
# 2010-01-19   30.741428   29.605715   29.761429   30.719999  182501900.0
# 2010-01-20   30.792856   29.928572   30.701429   30.247143  153038200.0
# ...

# %%
# Plot the closing prices for `yahoodata` with grid
yahooData['Close'].plot(grid=True)
# Show the plot
plt.show()

# %%
# Calculate Daily returns from closing price

daily_pct_change = yahooData['Adj Close'].pct_change()[1:]

print(daily_pct_change)
# Out:
# Date
# 2010-01-05    0.001729
# 2010-01-06   -0.015906
# 2010-01-07   -0.001849
# 2010-01-08    0.006648
# 2010-01-11   -0.008821
# 2010-01-12   -0.011375
# 2010-01-13    0.014105
# 2010-01-14   -0.005791
# 2010-01-15   -0.016712
# 2010-01-19    0.044238
# 2010-01-20   -0.015392
# 2010-01-21   -0.017286
# 2010-01-22   -0.049599
# 2010-01-25    0.026903
# 2010-01-26    0.014133
# 2010-01-27    0.009420
# 2010-01-28   -0.041322
# 2010-01-29   -0.036278
# 2010-02-01    0.013902
# 2010-02-02    0.005803
# 2010-02-03    0.017206
# 2010-02-04   -0.036039
# 2010-02-05    0.017756
# 2010-02-08   -0.006856
# 2010-02-09    0.010663
# 2010-02-10   -0.005453
# 2010-02-11    0.018193
# 2010-02-12    0.008608
# 2010-02-16    0.015071
# 2010-02-17   -0.004179
#                 ...
# 2017-11-17   -0.005552
# 2017-11-20   -0.000999
# 2017-11-21    0.018590
# 2017-11-22    0.010512
# 2017-11-24    0.000057
# 2017-11-27   -0.005030
# 2017-11-28   -0.005859
# 2017-11-29   -0.020743
# ...

# %%
# Print daily log returns
print(np.log(yahooData['Adj Close'].pct_change()[1:]+1))
# Out:
# Date
# 2010-01-05    0.001728
# 2010-01-06   -0.016034
# 2010-01-07   -0.001850
# 2010-01-08    0.006626
# 2010-01-11   -0.008861
# 2010-01-12   -0.011440
# 2010-01-13    0.014007
# 2010-01-14   -0.005808
# 2010-01-15   -0.016854
# 2010-01-19    0.043288
# 2010-01-20   -0.015512
# 2010-01-21   -0.017438
# 2010-01-22   -0.050871
# 2010-01-25    0.026547
# 2010-01-26    0.014034
# 2010-01-27    0.009376
# 2010-01-28   -0.042200
# 2010-01-29   -0.036953
# 2010-02-01    0.013806
# 2010-02-02    0.005786
# 2010-02-03    0.017060
# 2010-02-04   -0.036704
# 2010-02-05    0.017600
# 2010-02-08   -0.006879
# 2010-02-09    0.010607
# 2010-02-10   -0.005468
# 2010-02-11    0.018030
# 2010-02-12    0.008571
# 2010-02-16    0.014959
# 2010-02-17   -0.004188
#                 ...
# 2017-11-17   -0.005568
# 2017-11-20   -0.000999
# 2017-11-21    0.018420
# 2017-11-22    0.010457
# 2017-11-24    0.000057
# 2017-11-27   -0.005042
# 2017-11-28   -0.005876
# 2017-11-29   -0.020961
# ...

# %%
# Resample `yahooData` to business months, take last observation as value 
print(yahooData.resample('BM'))
# Out:
# DatetimeIndexResampler [freq=<BusinessMonthEnd>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
# Resample `YahooData` to quarters, take the mean as value per quarter
quarter = yahooData.resample("4M").mean()

# %%
print(quarter)
